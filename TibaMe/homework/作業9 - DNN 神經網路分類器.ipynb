# %% [markdown]
# # HW9 - DNN 神經網路分類器
# #### 【Python人工智慧實戰_2020-06-10】

# %%
# Import required libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn

# Import necessary modules
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt

# Keras specific
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('diabetes.csv') 
print(df.shape)
df.describe()
# Out:
# (768, 9)
#          pregnant     glucose          bp        skin     insulin         bmi  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#          pedigree         age       label
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# 50%      0.372500   29.000000    0.000000
# 75%      0.626250   41.000000    1.000000
# max      2.420000   81.000000    1.000000

# %%
target_column = ['label'] 
predictors = list(set(list(df.columns))-set(target_column))
df[predictors] = df[predictors]/df[predictors].max()
df.describe()
# Out:
#          pregnant     glucose          bp        skin     insulin         bmi  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     0.226180    0.607510    0.566438    0.207439    0.094326    0.476790
# std      0.198210    0.160666    0.158654    0.161134    0.136222    0.117499
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.058824    0.497487    0.508197    0.000000    0.000000    0.406855
# 50%      0.176471    0.587940    0.590164    0.232323    0.036052    0.476900
# 75%      0.352941    0.704774    0.655738    0.323232    0.150414    0.545455
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          pedigree         age       label
# count  768.000000  768.000000  768.000000
# mean     0.194990    0.410381    0.348958
# std      0.136913    0.145188    0.476951
# min      0.032231    0.259259    0.000000
# 25%      0.100723    0.296296    0.000000
# 50%      0.153926    0.358025    0.000000
# 75%      0.258781    0.506173    1.000000
# max      1.000000    1.000000    1.000000

# %%
X = df[predictors].values
y = df[target_column].values

seed = 40
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=seed)
print(X_train.shape); print(X_test.shape)
# Out:
# (537, 8)
# (231, 8)

# %%
# one hot encode outputs
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
learning_rate = 0.001
batch_size = 24
num_classes = y_test.shape[1] # 預測的類別數目
epochs = [50, 100, 150] # one epoch = Iterations（疊代）= N = numbers of training data/batch_size

# %%
def build_DNN(input_shape, output_units, num_neurons=[16, 24, 32, 64], drp_ratio=0.2):
    model = Sequential()
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            # num of features in input layer
            model.add(Dense(units=n_units, activation="relu", name="input", input_shape=[input_shape]))
        else:
            # add hidden layer
            model.add(Dense(units=n_units, activation="relu", name="hidden_layer" + str(i+1)))
            model.add(Dropout(drp_ratio)) # add dropout
            
    model.add(Dense(units=output_units, activation="softmax", name="output"))
    return model

# %%
def plt_model_result(result):
    num_colors = len(result.keys())
    cm = plt.get_cmap('gist_rainbow')
    color_bar = [cm(1. * i/num_colors) for i in range(num_colors)]
    
    plt.figure(figsize=(16, 9))
    for i, cond in enumerate(result.keys()):
        plt.plot(range(len(result[cond]['train-loss'])), result[cond]['train-loss'], '-', label = 'train-' + cond, color = color_bar[i])
        plt.plot(range(len(result[cond]['valid-loss'])), result[cond]['valid-loss'], '--', label = 'valid-' + cond, color = color_bar[i])
    plt.title("Loss")
    plt.legend()
    plt.show()    
    
    plt.figure(figsize=(16, 9))    
    for i, cond in enumerate(result.keys()):
        plt.plot(range(len(result[cond]['train-acc'])), result[cond]['train-acc'], '-', label = 'train-' + cond, color = color_bar[i])
        plt.plot(range(len(result[cond]['valid-acc'])), result[cond]['valid-acc'], '--', label = 'valid-' + cond, color = color_bar[i])
    plt.title("Accuracy")
    plt.legend()
    plt.show()

# %%
# build DNN model
model = build_DNN(X_test.shape[1], num_classes)

# summary model
model.summary()

# compile the model
optimizer = keras.optimizers.Adam(lr=learning_rate)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (Dense)                (None, 16)                144
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 24)                408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24)                0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 32)                800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                2112
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# output (Dense)               (None, 2)                 130
# =================================================================
# Total params: 3,594
# Trainable params: 3,594
# Non-trainable params: 0
# _________________________________________________________________

# %%
results = {}

# train model
model.fit(X_train, y_train, batch_size=batch_size, validation_data = (X_test, y_test), epochs=150, verbose=1)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]
# Out:
# Train on 537 samples, validate on 231 samples
# Epoch 1/150
# 537/537 [==============================] - 0s 753us/step - loss: 0.6549 - accuracy: 0.6406 - val_loss: 0.6670 - val_accuracy: 0.6147
# Epoch 2/150
# 537/537 [==============================] - 0s 106us/step - loss: 0.6479 - accuracy: 0.6667 - val_loss: 0.6492 - val_accuracy: 0.6147
# Epoch 3/150
# 537/537 [==============================] - 0s 119us/step - loss: 0.6306 - accuracy: 0.6741 - val_loss: 0.6440 - val_accuracy: 0.6190
# Epoch 4/150
# 537/537 [==============================] - 0s 98us/step - loss: 0.6084 - accuracy: 0.6965 - val_loss: 0.6259 - val_accuracy: 0.6407
# Epoch 5/150
# 537/537 [==============================] - 0s 115us/step - loss: 0.5953 - accuracy: 0.6853 - val_loss: 0.6050 - val_accuracy: 0.6797
# Epoch 6/150
# 537/537 [==============================] - 0s 108us/step - loss: 0.5832 - accuracy: 0.7039 - val_loss: 0.5984 - val_accuracy: 0.6753
# Epoch 7/150
# 537/537 [==============================] - 0s 106us/step - loss: 0.5865 - accuracy: 0.6890 - val_loss: 0.5848 - val_accuracy: 0.7100
# Epoch 8/150
# 537/537 [==============================] - 0s 115us/step - loss: 0.5832 - accuracy: 0.6927 - val_loss: 0.5791 - val_accuracy: 0.7100
# Epoch 9/150
# 537/537 [==============================] - 0s 119us/step - loss: 0.5579 - accuracy: 0.7281 - val_loss: 0.5834 - val_accuracy: 0.7186
# Epoch 10/150
# 537/537 [==============================] - 0s 108us/step - loss: 0.5449 - accuracy: 0.7430 - val_loss: 0.5802 - val_accuracy: 0.7273
# Epoch 11/150
# 537/537 [==============================] - 0s 115us/step - loss: 0.5385 - accuracy: 0.7300 - val_loss: 0.5498 - val_accuracy: 0.7446
# Epoch 12/150
# 537/537 [==============================] - 0s 115us/step - loss: 0.5326 - accuracy: 0.7523 - val_loss: 0.5460 - val_accuracy: 0.7446
# Epoch 13/150
# 537/537 [==============================] - 0s 117us/step - loss: 0.5197 - accuracy: 0.7505 - val_loss: 0.5404 - val_accuracy: 0.7013
# Epoch 14/150
# 537/537 [==============================] - 0s 119us/step - loss: 0.5227 - accuracy: 0.7393 - val_loss: 0.5410 - val_accuracy: 0.6970
# Epoch 15/150
# 537/537 [==============================] - 0s 117us/step - loss: 0.5130 - accuracy: 0.7467 - val_loss: 0.5325 - val_accuracy: 0.7316
# Epoch 16/150
# 537/537 [==============================] - 0s 119us/step - loss: 0.4962 - accuracy: 0.7635 - val_loss: 0.5319 - val_accuracy: 0.7316
# Epoch 17/150
# 537/537 [==============================] - 0s 162us/step - loss: 0.5062 - accuracy: 0.7523 - val_loss: 0.5269 - val_accuracy: 0.7359
# Epoch 18/150
# 537/537 [==============================] - 0s 141us/step - loss: 0.4851 - accuracy: 0.7728 - val_loss: 0.5233 - val_accuracy: 0.7229
# Epoch 19/150
# 537/537 [==============================] - 0s 136us/step - loss: 0.5037 - accuracy: 0.7728 - val_loss: 0.5184 - val_accuracy: 0.7273
# Epoch 20/150
# 537/537 [==============================] - 0s 148us/step - loss: 0.5062 - accuracy: 0.7449 - val_loss: 0.5250 - val_accuracy: 0.7489
# Epoch 21/150
# 537/537 [==============================] - 0s 112us/step - loss: 0.4746 - accuracy: 0.7747 - val_loss: 0.5345 - val_accuracy: 0.7403
# Epoch 22/150
# 537/537 [==============================] - 0s 110us/step - loss: 0.4882 - accuracy: 0.7784 - val_loss: 0.5362 - val_accuracy: 0.7489
# Epoch 23/150
# 537/537 [==============================] - 0s 137us/step - loss: 0.4793 - accuracy: 0.7654 - val_loss: 0.5133 - val_accuracy: 0.7403
# Epoch 24/150
# 537/537 [==============================] - 0s 160us/step - loss: 0.4938 - accuracy: 0.7486 - val_loss: 0.5278 - val_accuracy: 0.7359
# Epoch 25/150
# 537/537 [==============================] - 0s 117us/step - loss: 0.
150
# 537/537 [==============================] - 0s 97us/step - loss: 0.4020 - accuracy: 0.8101 - val_loss: 0.5473 - val_accuracy: 0.7316
# Epoch 131/150
# 537/537 [==============================] - 0s 97us/step - loss: 0.3954 - accuracy: 0.8212 - val_loss: 0.5311 - val_accuracy: 0.7273
# Epoch 132/150
# 537/537 [==============================] - 0s 102us/step - loss: 0.4026 - accuracy: 0.8082 - val_loss: 0.5304 - val_accuracy: 0.7403
# Epoch 133/150
# 537/537 [==============================] - 0s 95us/step - loss: 0.3954 - accuracy: 0.8156 - val_loss: 0.5220 - val_accuracy: 0.7359
# Epoch 134/150
# 537/537 [==============================] - 0s 93us/step - loss: 0.4099 - accuracy: 0.8101 - val_loss: 0.5488 - val_accuracy: 0.7489
# Epoch 135/150
# 537/537 [==============================] - 0s 121us/step - loss: 0.3957 - accuracy: 0.8082 - val_loss: 0.5770 - val_accuracy: 0.7359
# Epoch 136/150
# 537/537 [==============================] - 0s 123us/step - loss: 0.3876 - accuracy: 0.8287 - val_loss: 0.5654 - val_accuracy: 0.7316
# Epoch 137/150
# 537/537 [==============================] - 0s 132us/step - loss: 0.3879 - accuracy: 0.8063 - val_loss: 0.5691 - val_accuracy: 0.7359
# Epoch 138/150
# 537/537 [==============================] - 0s 110us/step - loss: 0.3998 - accuracy: 0.8101 - val_loss: 0.5481 - val_accuracy: 0.7316
# Epoch 139/150
# 537/537 [==============================] - 0s 128us/step - loss: 0.3953 - accuracy: 0.8212 - val_loss: 0.5612 - val_accuracy: 0.7316
# Epoch 140/150
# 537/537 [==============================] - 0s 124us/step - loss: 0.3735 - accuracy: 0.8175 - val_loss: 0.5941 - val_accuracy: 0.7532
# Epoch 141/150
# 537/537 [==============================] - 0s 98us/step - loss: 0.3804 - accuracy: 0.8305 - val_loss: 0.5498 - val_accuracy: 0.7532
# Epoch 142/150
# 537/537 [==============================] - 0s 110us/step - loss: 0.3840 - accuracy: 0.8119 - val_loss: 0.5645 - val_accuracy: 0.7316
# Epoch 143/150
# 537/537 [==============================] - 0s 141us/step - loss: 0.3810 - accuracy: 0.8175 - val_loss: 0.5516 - val_accuracy: 0.7229
# Epoch 144/150
# 537/537 [==============================] - 0s 137us/step - loss: 0.3844 - accuracy: 0.8156 - val_loss: 0.5402 - val_accuracy: 0.7273
# Epoch 145/150
# 537/537 [==============================] - 0s 141us/step - loss: 0.3840 - accuracy: 0.8231 - val_loss: 0.5717 - val_accuracy: 0.7446
# Epoch 146/150
# 537/537 [==============================] - 0s 154us/step - loss: 0.3946 - accuracy: 0.8045 - val_loss: 0.5646 - val_accuracy: 0.7446
# Epoch 147/150
# 537/537 [==============================] - 0s 154us/step - loss: 0.3932 - accuracy: 0.8156 - val_loss: 0.5793 - val_accuracy: 0.7532
# Epoch 148/150
# 537/537 [==============================] - 0s 137us/step - loss: 0.3834 - accuracy: 0.8268 - val_loss: 0.5730 - val_accuracy: 0.7273
# Epoch 149/150
# 537/537 [==============================] - 0s 111us/step - loss: 0.3856 - accuracy: 0.8287 - val_loss: 0.5892 - val_accuracy: 0.7489
# Epoch 150/150
# 537/537 [==============================] - 0s 106us/step - loss: 0.4046 - accuracy: 0.8175 - val_loss: 0.5703 - val_accuracy: 0.7532

# %%
print("Experiment with Epoch: %.0f, Dropout: %.2f\n" % (150, 0.2))
scores = model.evaluate(X_train, y_train, verbose=0)
print('Accuracy on training data: {}% \nError on training data: {}'.format(scores[1], 1 - scores[1]))   
 
pred_test= model.predict(X_test)
scores2 = model.evaluate(X_test, y_test, verbose=0)
print('Accuracy on test data: {}% \nError on test data: {}'.format(scores2[1], 1 - scores2[1]))
# Out:
# Experiment with Epoch: 150, Dropout: 0.20
#
# Accuracy on training data: 0.8342644572257996%
# Error on training data: 0.16573554277420044
# Accuracy on test data: 0.7532467246055603%
# Error on test data: 0.2467532753944397

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.subplots_adjust(left=0.5)
plt.figure(figsize=(16, 4))

plt.subplot(1, 2, 1)
plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show

plt.subplot(1, 2, 2)
plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %%
# compare with different epoch & drop_ratio
import itertools

'''
 verbose=0 show nothing of training progress
 verbose=1 show an animated progress bar of training progress like: [==============================]
 verbose=2 mention the number of epoch like: Epoch 16/100
'''

results = {}
drp_ratios = [0.2, 0.4]
for epoch, drop_rate in itertools.product(epochs, drp_ratios):
    keras.backend.clear_session() # 把舊的 Graph 清掉
    
    # build DNN model
    model = build_DNN(X_test.shape[1], num_classes, drp_ratio=drop_rate)
    
    # summary model
    model.summary()
    
    # compile the model
    optimizer = keras.optimizers.Adam(lr=learning_rate)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    # train model
    model.fit(X_train, y_train, batch_size=batch_size, validation_data = (X_test, y_test), epochs=epoch, verbose=0)
    
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    
    exp_name_tag = 'Epoch:{}, Dropout: {}'.format(str(epoch), str(drop_rate))
    results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}
    
    print("Experiment with Epoch: %.0f, Dropout: %.2f\n" % (epoch, drop_rate))
    scores = model.evaluate(X_train, y_train, verbose=0)
    print('Accuracy on training data: {}% \nError on training data: {}'.format(scores[1], 1 - scores[1]))
    
    pred_test= model.predict(X_test)
    scores2 = model.evaluate(X_test, y_test, verbose=0)
    print('Accuracy on test data: {}% \nError on test data: {}\n'.format(scores2[1], 1 - scores2[1]))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (Dense)                (None, 16)                144
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 24)                408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24)                0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 32)                800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                2112
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# output (Dense)               (None, 2)                 130
# =================================================================
# Total params: 3,594
# Trainable params: 3,594
# Non-trainable params: 0
# _________________________________________________________________
# Experiment with Epoch: 50, Dropout: 0.20
#
# Accuracy on training data: 0.80633145570755%
# Error on training data: 0.19366854429244995
# Accuracy on test data: 0.7359307408332825%
# Error on test data: 0.26406925916671753
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (Dense)                (None, 16)                144
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 24)                408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24)                0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 32)                800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                2112
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# output (Dense)               (None, 2)                 130
# =================================================================
# Total params: 3,594
# Trainable params: 3,594
# Non-trainable params: 0
# _________________________________________________________________
# Experiment with Epoch: 50, Dropout: 0.40
#
# Accuracy on training data: 0.8026070594787598%
# Error on training data: 0.19739294052124023
# Accuracy on test data: 0.7575757503509521%
# Error on test data: 0.24242424964904785
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (Dense)                (None, 16)                144
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 24)                408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24)                0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 32)                800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                2112
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# output (Dense)               (None, 2)                 130
# =================================================================
# Total params: 3,594
# Trainable params: 3,594
# Non-trainable params: 0
# _________________________________________________________________
# Experiment with Epoch: 100, Dropout: 0.20
#
# Accuracy on training data: 0.826815664768219%
# Error on training data: 0.173184335231781
# Accuracy on test data: 0.7142857313156128%
# Error on test data: 0.2857142686843872
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (Dense)                (None, 16)                144
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 24)                408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24)                0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 32)                800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                2112
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# output (Dense)               (None, 2)                 130
# =================================================================
# Total params: 3,594
# Trainable params: 3,594
# Non-trainable params: 0
# _________________________________________________________________
# Experiment with Epoch: 100, Dropout: 0.40
#
# Accuracy on training data: 0.8044692873954773%
# Error on training data: 0.1955307126045227
# Accuracy on test data: 0.7272727489471436%
# Error on test data: 0.27272725105285645
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (Dense)                (None, 16)                144
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 24)                408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24)                0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 32)                800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                2112
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# output (Dense)               (None, 2)                 130
# =================================================================
# Total params: 3,594
# Trainable params: 3,594
# Non-trainable params: 0
# _________________________________________________________________
# Experiment with Epoch: 150, Dropout: 0.20
#
# Accuracy on training data: 0.8528863787651062%
# Error on training data: 0.1471136212348938
# Accuracy on test data: 0.7662337422370911%
# Error on test data: 0.23376625776290894
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (Dense)                (None, 16)                144
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 24)                408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24)                0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 32)                800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                2112
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# output (Dense)               (None, 2)                 130
# =================================================================
# Total params: 3,594
# Trainable params: 3,594
# Non-trainable params: 0
# _________________________________________________________________
# Experiment with Epoch: 150, Dropout: 0.40
#
# Accuracy on training data: 0.8081936836242676%
# Error on training data: 0.19180631637573242
# Accuracy on test data: 0.7402597665786743%
# Error on test data: 0.2597402334213257

# %%
plt_model_result(results)
